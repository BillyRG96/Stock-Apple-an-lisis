# %% [markdown]
# 1. Carga de modulos y documento csv de stock

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
dataset = pd.read_csv("AAPL.csv")

# %%
dataset.head(100)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume
# 0   1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1   1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2   1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3   1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4   1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400
# ..         ...       ...       ...       ...       ...        ...        ...
# 95  1981-04-30  0.506696  0.511161  0.506696  0.506696   0.401476    3152800
# 96  1981-05-01  0.506696  0.511161  0.506696  0.506696   0.401476    4138400
# 97  1981-05-04  0.506696  0.506696  0.504464  0.504464   0.399707    3612000
# 98  1981-05-05  0.504464  0.504464  0.502232  0.502232   0.397938    4384800
# 99  1981-05-06  0.491071  0.491071  0.488839  0.488839   0.387327    4737600
#
# [100 rows x 7 columns]

# %% [markdown]
# 2. Panorama general de los datos procesados.

# %%
dataset.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9909.000000  9909.000000  9909.000000  9909.000000  9909.000000
# mean     32.606849    32.936079    32.277560    32.618030    30.576570
# std      58.415759    59.001576    57.883037    58.471899    56.746275
# min       0.198661     0.198661     0.196429     0.196429     0.155638
# 25%       1.071429     1.089286     1.048571     1.071429     0.917643
# 50%       1.729286     1.758929     1.696429     1.732143     1.466154
# 75%      35.799999    36.265713    35.328571    35.761429    31.042374
# max     324.739990   327.850006   323.350006   327.200012   327.200012
#
#              Volume
# count  9.909000e+03
# mean   8.582916e+07
# std    8.597195e+07
# min    3.472000e+05
# 25%    3.304230e+07
# 50%    5.766490e+07
# 75%    1.069992e+08
# max    1.855410e+09

# %% [markdown]
# 3. Análisis de datos - Visualización del Volumen de accion APPLE desde 1980 hasta 2021.

# %%
años = dataset['Date']
plt.figure(figsize=(15,5))
plt.plot(pd.to_datetime(años), dataset['Volume'])
plt.show()

# %% [markdown]
# 4. Comportamiento de los valores mas altos y de apetura de la acción a los largo del tiempo.

# %%
años = dataset['Date']
plt.figure(figsize=(20,5))
plt.plot(pd.to_datetime(años), dataset['Open'])
plt.plot(pd.to_datetime(años), dataset["High"])
plt.show()

# %%
años = dataset['Date']
plt.figure(figsize=(15,5))
plt.scatter(dataset['Open'],  dataset['Close'])
plt.show()

# %%
años = dataset['Date']
plt.figure(figsize=(15,5))
plt.scatter(dataset['Open'],  dataset['Close'])
plt.show()

# %% [markdown]
# 5. Comportamiento de los valores más altos de la acción, lineas de tendencia, media, max y min.

# %%
plt.figure(figsize=(15,5))
plt.plot(pd.to_datetime(dataset["Date"]), dataset['High'])
plt.axhline(y=max(dataset["High"]))
plt.axhline(y=np.mean((dataset["High"])))
plt.axhline(y=min(dataset["High"]))
plt.show()

# %%
max(dataset["High"])
# Out:
# 327.8500061035156

# %%
años = dataset['Date']
plt.figure(figsize=(15,5))
plt.scatter(dataset['Open'],  dataset['Low'])
plt.show()

# %%
años = dataset['Date']
plt.figure(figsize=(15,5))
plt.scatter(dataset['Volume'],  dataset['Low'])
plt.show()

# %% [markdown]
# 6. Comportamiento de la acción en determinado año(2020).

# %%
n = 2020
fecha = pd.to_datetime(dataset["Date"])
año = dataset[fecha.dt.year == n]
filtro_año =año["Date"]
filtro_cierre =año["Close"]
filtro_Volume = año["Volume"]
plt.figure(figsize=(15,5))
plt.plot(pd.to_datetime(filtro_año), filtro_cierre)
#plt.plot(pd.to_datetime(año), dataset['Open'].head(len(año)))
plt.axhline(y=max(dataset["Close"][fecha.dt.year == n]))
#plt.axhline(y=np.mean((dataset["High"])))
plt.axhline(y=min(dataset["Close"][fecha.dt.year == n]))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 7. Contraste entre el comportamiento de la acción y el volument generado durante su movimiento.

# %%
fig, ax = plt.subplots(2, 1)
fig.set_size_inches(15, 8)
ax[0].plot(pd.to_datetime(filtro_año), filtro_cierre)
ax[1].bar(pd.to_datetime(filtro_año), filtro_Volume)
plt.show()

# %% [markdown]
# 8. Fechas de relevancia en valores altos en cierres de la accion.

# %%
Altos_totales = []
for n in np.arange(1980, 2021, 1):
    Altos_por_año = dataset[dataset["Close"] == max(dataset["Close"][fecha.dt.year == n])]["Date"][fecha.dt.year == n]
    Altos_totales.append(Altos_por_año)


print(Altos_totales)
# Out:
# [10    1980-12-29
# Name: Date, dtype: object, 13    1981-01-02
# Name: Date, dtype: object, 500    1982-12-07
# Name: Date, dtype: object, 625    1983-06-06
# Name: Date, dtype: object, 854    1984-05-01
# Name: Date, dtype: object, 1032    1985-01-14
# Name: Date, dtype: object, 1511    1986-12-05
# Name: Date, dtype: object, 1720    1987-10-05
# Name: Date, dtype: object, 1909    1988-07-05
# Name: Date, dtype: object, 2148    1989-06-14
# Name: Date, dtype: object, 2420    1990-07-12
# Name: Date, dtype: object, 2602    1991-04-02
# Name: Date, dtype: object, 2831    1992-02-26
# Name: Date, dtype: object, 3055    1993-01-14
# Name: Date, dtype: object, 3506    1994-10-26
# Name: Date, dtype: object, 3670    1995-06-21
# Name: Date, dtype: object, 3811    1996-01-11
# Name: Date, dtype: object, 4209    1997-08-07
# Name: Date, dtype: object, 4471    1998-08-21
# Name: Date, dtype: object, 4797    1999-12-07
# Name: Date, dtype: object, 4870    2000-03-22
# ...

# %%
Altos_totales = []
for n in np.arange(1980, 2021, 1):
    Altos_por_año = dataset[dataset["Close"] == min(dataset["Close"][fecha.dt.year == n])]["Date"][fecha.dt.year == n]
    Altos_totales.append(Altos_por_año)
    
for i in Altos_totales:
    print(i.values)
# Out:
# ['1980-12-16']
# ['1981-09-25']
# ['1982-07-08']
# ['1983-11-08']
# ['1984-11-19']
# ['1985-08-15']
# ['1986-01-27']
# ['1987-01-02']
# ['1988-11-22']
# ['1989-03-27' '1989-12-15']
# ['1990-10-16']
# ['1991-06-14']
# ['1992-08-24']
# ['1993-10-08']
# ['1994-06-23']
# ['1995-12-29']
# ['1996-07-16' '1996-07-17']
# ['1997-12-23']
# ['1998-01-05']
# ['1999-03-11']
# ['2000-12-19']
# ['2001-01-02']
# ['2002-10-09']
# ['2003-04-17']
# ['2004-01-02']
# ['2005-01-03']
# ['2006-07-14']
# ['2007-02-09']
# ['2008-11-20']
# ['2009-01-20']
# ['2010-02-04']
# ['2011-06-20']
# ['2012-01-03']
# ['2013-04-19']
# ['2014-01-30']
# ['2015-08-24']
# ['2016-05-12']
# ['2017-01-04']
# ['2018-12-24']
# ['2019-01-03']
# ['2020-03-23']

# %% [markdown]
# Predicción del precio de cierre de la acción.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


X = dataset.iloc[:, [1, 2, 3]].values
y = dataset.iloc[:, 4].values
#X[1:, 0] = X[1:, 0].astype(float)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)


from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)
error = np.sqrt((y_pred - y_test)**2)
# Out:
# 1.326080900554416e-05

# %%
print(max(error))
print(min(error))
print(np.mean(error))
# Out:
# 8.261039355088684
# 1.326080900554416e-05
# 0.15808778131820453

# %% [markdown]
# Comparación de la predicción y los precios reales de cierrre.

# %%
for i in np.arange(1, 30, 1):
    a = y_test[i], y_pred[i]
    print(a)
# Out:
# (0.8147321343421936, 0.8168105738217677)
# (0.959999978542328, 0.945791348521572)
# (1.3727678060531616, 1.3915791399912254)
# (0.9642857313156128, 0.9689297394633097)
# (1.6339285373687744, 1.6363832639369695)
# (61.04142761230469, 60.8330776638872)
# (1.4308035373687744, 1.4617902289493598)
# (115.20999908447266, 115.02501850335639)
# (19.368572235107425, 19.38007631719283)
# (0.8839285969734192, 0.8794211479260761)
# (20.722856521606445, 20.64019775699893)
# (1.6607142686843872, 1.6678792246686311)
# (1.3035714626312256, 1.362440949297953)
# (6.137142658233643, 6.115132226816394)
# (2.017857074737549, 2.0235169494951633)
# (1.2321428060531616, 1.2315174328821161)
# (1.6964285373687744, 1.7213062173998877)
# (12.875714302062988, 13.054142618972204)
# (0.6517857313156128, 0.6511709153770362)
# (65.85857391357422, 65.66207977005533)
# (2.15625, 2.159287433733815)
# (208.4900054931641, 207.63485767650752)
# (2.080357074737549, 2.0714162433730596)
# ...

# %% [markdown]
# Relación entre el precio de cierre real y la predicción del momdelo.

# %%
plt.scatter(y_pred, y_test)
